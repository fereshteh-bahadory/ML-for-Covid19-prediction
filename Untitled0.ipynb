# %% [markdown]
# <a href="https://colab.research.google.com/github/fereshteh-bahadory/ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import io
import sklearn
from matplotlib import pyplot as plt
import seaborn as sb
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8b4a567d-92b3-4a0a-976e-d96a4320272f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b4a567d-92b3-4a0a-976e-d96a4320272f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving country_vaccinations.csv to country_vaccinations (1).csv

# %%
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-05fb5e7a-1ace-48b5-9ae1-3f740ca5fa19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05fb5e7a-1ace-48b5-9ae1-3f740ca5fa19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving country_vaccinations_by_manufacturer.csv to country_vaccinations_by_manufacturer (1).csv

# %%
data1=pd.read_csv(io.BytesIO(uploaded['country_vaccinations.csv']))
data1.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
data2=pd.read_csv(io.BytesIO(uploaded2['country_vaccinations_by_manufacturer.csv']))
data2.head()
# Out:
#   location        date             vaccine  total_vaccinations
# 0  Austria  2021-01-08     Johnson&Johnson                   0
# 1  Austria  2021-01-08             Moderna                   0
# 2  Austria  2021-01-08  Oxford/AstraZeneca                   0
# 3  Austria  2021-01-08     Pfizer/BioNTech               30974
# 4  Austria  2021-01-15     Johnson&Johnson                   0

# %%
data1.info()
data1.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31240 entries, 0 to 31239
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              31240 non-null  object
#  1   iso_code                             31240 non-null  object
#  2   date                                 31240 non-null  object
#  3   total_vaccinations                   17451 non-null  float64
#  4   people_vaccinated                    16554 non-null  float64
#  5   people_fully_vaccinated              13795 non-null  float64
#  6   daily_vaccinations_raw               14421 non-null  float64
#  7   daily_vaccinations                   30948 non-null  float64
#  8   total_vaccinations_per_hundred       17451 non-null  float64
#  9   people_vaccinated_per_hundred        16554 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13795 non-null  float64
# ...

# %%
data1.describe(include='all')
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# count    31240    31240       31240        1.745100e+04       1.655400e+04
# unique     218      218         226                 NaN                NaN
# top     Norway      NOR  2021-06-02                 NaN                NaN
# freq       226      226         209                 NaN                NaN
# mean       NaN      NaN         NaN        1.200444e+07       5.704551e+06
# std        NaN      NaN         NaN        6.622349e+07       2.101612e+07
# min        NaN      NaN         NaN        0.000000e+00       0.000000e+00
# 25%        NaN      NaN         NaN        1.262015e+05       9.999100e+04
# 50%        NaN      NaN         NaN        8.890780e+05       6.450395e+05
# 75%        NaN      NaN         NaN        4.213660e+06       2.809300e+06
# max        NaN      NaN         NaN        1.426347e+09       6.220000e+08
#
# ...

# %%
fig, ax = plt.subplots(figsize=[10,4])
sb.distplot(data1['total_vaccinations'], ax=ax)
ax.set_title('Total Vaccinations')
plt.show()

# %%
fig, ax = plt.subplots(figsize=[10,4])
sb.distplot(data1['daily_vaccinations'], ax=ax)
ax.set_title('Daily Vaccinations')
plt.show()

# %%
data1.hist(figsize=(20,20))
plt.show()
